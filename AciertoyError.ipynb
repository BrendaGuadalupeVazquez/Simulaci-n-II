# %% [markdown]
# <a href="https://colab.research.google.com/github/BrendaGuadalupeVazquez/Simulaci-n-II/blob/main/AciertoyError.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Método de Monte Carlo**

# %% [markdown]
# Acierto y error

# %%
import matplotlib.pyplot as plt #libreria para graficar
import numpy as np
import random as rd #libreria para generar numeros aleatorios

# %%
def f(x):
  return np.sqrt(np.arctan(x))#la funcion de la cual queremos graficar y sproximar su integral

# %%
aciertos=0 #numero de puntitos bajo la curva
n=1000 #numero de puntitos

# %%
#generadores de puntos x & y aleatorios
x=rd.random()
y=rd.random()

# %%
a=np.linspace(0,1,100)
b=f(a)

# %%
plt.plot(a,b,color='blue')
plt.scatter(x,y,color='green')

# %%
for i in range(1000):
  x=rd.random()
  y=rd.random()
  plt.plot(a,b,color='blue')
  plt.scatter(x,y,color='green')

# %%
for i in range(n):
  x=rd.random()
  y=rd.random()
  plt.plot(a,b,color='red')
  if y<=f(x):
    plt.scatter(x,y,color='green')
    aciertos+=1
  else: plt.scatter(x,y,color='yellow')

# %%
aciertos
# Out:
# 618

# %%
I=aciertos/n

# %%
I
# Out:
# 0.618
